# %%
import subprocess
from graphviz import Source

# %% [markdown]
# ## badThread

# %%
# TODO: Now, main.go is updated and returns different dot file content. Add feature to select which main.go to run.
result = subprocess.run(['go', 'run', 'modelchecker'], stdout=subprocess.PIPE, text=True)
dot_file_content = result.stdout
Source(dot_file_content)

# %% [markdown]
# ## GoodThread

# %%
result = subprocess.run(['go', 'run', 'modelchecker'], stdout=subprocess.PIPE, text=True)
dot_file_content = result.stdout
Source(dot_file_content)

# %% [markdown]
# ## DiningBadPhilosopher

# %%
result = subprocess.run(['go', 'run', 'modelchecker'], stdout=subprocess.PIPE, text=True)
dot_file_content = result.stdout
Source(dot_file_content)

# %%
result = subprocess.run(['go', 'run', 'modelchecker'], stdout=subprocess.PIPE, text=True)
dot_file_content = result.stdout
Source(dot_file_content)

# %%
result = subprocess.run(['go', 'run', 'modelchecker'], stdout=subprocess.PIPE, text=True)
dot_file_content = result.stdout
Source(dot_file_content)
