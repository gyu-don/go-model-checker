# %%
import subprocess
from graphviz import Source

# %% [markdown]
# ## badThread

# %%
result = subprocess.run(['go', 'run', 'main'], stdout=subprocess.PIPE, text=True)
dot_file_content = result.stdout
Source(dot_file_content)
